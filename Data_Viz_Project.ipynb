# %% [markdown]
# <a href="https://colab.research.google.com/github/desiree-1234/Hello-World/blob/main/Data_Viz_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Standard opening

import pandas as pd

pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns
dataframe = "df"
print("Setup Complete")

#Path of the file to read
cocoa = ("/content/drive/MyDrive/3.3_EDA&Data_visualisation (1).zip (Unzipped Files)/Chocolate.csv")
df = pd.read_csv(cocoa, index_col="Bean")

#Review Data
df.head
# Out:
# Setup Complete
# <bound method NDFrame.head of             Company    Bean or Bar Name  Date % Cocoa Company.1  Rating  \
# Bean
# Mixed      A. Morin         Agua Grande  2016     63%    France    3.75
# Mixed      A. Morin               Kpime  2015     70%    France    2.75
# Mixed      A. Morin              Atsane  2015     70%    France    3.00
# Mixed      A. Morin               Akata  2015     70%    France    3.50
# Mixed      A. Morin              Quilla  2015     70%    France    3.50
# ...             ...                 ...   ...     ...       ...     ...
# Mixed        Zotter                Peru  2011     70%   Austria    3.75
# Forastero    Zotter               Congo  2011     65%   Austria    3.00
# Forastero    Zotter        Kerala State  2011     65%   Austria    3.50
# Mixed        Zotter        Kerala State  2011     62%   Austria    3.25
# Mixed        Zotter  Brazil, Mitzi Blue  2010     65%   Austria    3.00
#
#           Bean Origin
# Bean
# ...

# %%
#Standard opening

import pandas as pd

pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns
dataframe = "df"
print("Setup Complete")

#Path of the file to read
cocoa = ("/content/drive/MyDrive/3.3_EDA&Data_visualisation (1).zip (Unzipped Files)/Chocolate.csv")
cocoa = pd.read_csv(cocoa, index_col="Bean", parse_dates=True)

# Plot Data

list(cocoa.columns)
# Out:
# Setup Complete
# ['Company',
#  'Bean or Bar Name',
#  'Date',
#  '% Cocoa',
#  'Company.1',
#  'Rating',
#  'Bean Origin']

# %%
plt.figure(figsize=(35,30))
plt.title("Cocoa Production by Year")
sns.lineplot(data=cocoa['Bean Origin'], label= "Bean Origin")
plt.xlabel('Rating')
# Out:
# Text(0.5, 0, 'Rating')
